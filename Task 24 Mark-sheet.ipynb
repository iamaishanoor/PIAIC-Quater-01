# %% [markdown]
# # Marksheet

# %%
#student basic information
name = input("Enter your Name: ")
father_name = input("Enter your Father Name: ")
rollno = input("Enter your Roll NO: ")
institute_name = input("Enter your Institute Name: ")
degree = input("Enter your Degree: ")
semester =input("Enter your Semester: ")

#name of the subjects
english = int(input("Enter the marks of English: "))
urdu = int(input("Enter the marks of Urdu: "))
chemistry = int(input("Enter the marks of Chemistry: "))
physics = int(input("Enter the marks of Physics: "))
maths = int(input("Enter the marks of Mathematics: "))
computer = int(input("Enter the marks of Computer: "))

#sum of all the marks
total = english + urdu + chemistry + maths + physics + computer

#status of each subject
if english >= 40:
    estatus="PASS"
else:
    estatus = "FAIL"
if urdu>=40:
    ustatus = "PASS"
else:
    ustatus = "FAIL"

if chemistry>=40:
    cstatus = "PASS"
else:
    cstatus = "FAIL"

if physics>=40:
    pstatus = "PASS"
else:
    pstatus = "FAIL"

if maths>=40:
    mstatus = "PASS"
else:
    mstatus = "FAIL"

if computer>=40:
    costatus = "PASS"
else:
    costatus = "FAIL"

#status of final garde   
if estatus == "PASS" and ustatus == "PASS"  and mstatus == "PASS"  and pstatus == "PASS"  and cstatus == "PASS" and costatus == "PASS" :
    finalstatus = "PASS"
    percentage = (total*100)/600
    percentage = round(percentage,2)
else:
    finalstatus = "FAIL"
    percentage = "-"

#grade of each subject    
if english>=40 and english<50:
    egrade= "D"
elif english>=50 and english<60:
    egrade="C"
elif english>=60 and english<70:
    egrade="B"
elif english>=70 and english<80:
    egrade="B+"
elif english>=80 and english<90:
    egrade="A"
elif english>=90 and english<100:
    egrade="A+"
else:
    egrade = "-"

if urdu>=40 and urdu<50:
    ugrade= "D"
elif urdu>=50 and urdu<60:
    ugrade="C"
elif urdu>=60 and urdu<70:
    ugrade="B"
elif urdu>=70 and urdu<80:
    ugrade="B+"
elif urdu>=80 and urdu<90:
    ugrade="A"
elif urdu>=90 and urdu<100:
    ugrade="A+"
else:
    ugrade = "-"


if chemistry>=40 and chemistry<50:
    cgrade= "D"
elif chemistry>=50 and chemistry<60:
    cgrade="C"
elif chemistry>=60 and chemistry<70:
    cgrade="B"
elif chemistry>=70 and chemistry<80:
    cgrade="B+"
elif chemistry>=80 and chemistry<90:
    cgrade="A"
elif chemistry>=90 and chemistry<100:
    cgrade="A+"
else:
    cgrade = "-"

if physics>=40 and physics<50:
    pgrade= "D"
elif physics>=50 and physics<60:
    pgrade="C"
elif physics>=60 and physics<70:
    pgrade="B"
elif physics>=70 and physics<80:
    pgrade="B+"
elif physics>=80 and physics<90:
    pgrade="A"
elif physics>=90 and physics<100:
    pgrade="A+"
else:
    pgrade = "-"

if maths>=40 and maths<50:
    mgrade= "D"
elif maths>=50 and maths<60:
    mgrade="C"
elif maths>=60 and maths<70:
    mgrade="B"
elif maths>=70 and maths<80:
    mgrade="B+"
elif maths>=80 and maths<90:
    mgrade="A"
elif maths>=90 and maths<100:
    mgrade="A+"
else:
    mgrade = "-"


if computer>=40 and computer<50:
    cograde= "D"
elif computer>=50 and computer<60:
    cograde="C"
elif computer>=60 and computer<70:
    cograde="B"
elif computer>=70 and computer<80:
    cograde="B+"
elif computer>=80 and computer<90:
    cograde="A"
elif computer>=90 and computer<=100:
    cograde="A+"
else:
    cograde = "-"
    
#final grade
if finalstatus == "PASS":
    if total>=240 and total<300:
        finalgrade = "D"
    elif total>=300 and total<400:
        finalgarde = "C"
    elif total>=400 and total<500:
        finalgrade= "B"
    elif total>=500 and total<550:
        finalgrade = "A"
    elif total>=550 and total<=600:
        finalgrade = "A+"
    else:
        finalgrade = "-"
    
else:
    finalgrade = "-"

print("----------------------------------------------------------------------------------------------------------------")
print(" Student Name: " +name)
print(" Student Father's Name: "+father_name)
print(" Studnet Roll No: " +rollno)
print(" Institute Name: " +institute_name) 
print(" Student Degree: "+degree)
print("|===============================================================================================================|")
print("|\t\t\t\t\t\t"+semester+" SEMESTER MARKSHEET\t\t\t\t\t\t|")
print("|_______________________________________________________________________________________________________________|")
print("|\t\t|  SUBJECTS     |  MAX-MARKS   |   OBTAINED MARKS  |   STATUS   |     GARDE     |\t\t|")
print("|_______________|_______________|______________|___________________|____________|_______________|_______________|")
print("|\t\t| English       |    100       | \t" +str(english)+"\t   | \t"+str(estatus)+ "\t|\t"+str(egrade)+"\t|\t\t|" )
print("|\t\t| Urdu          |    100       | \t" +str(urdu)+"\t   | \t"+str(ustatus)+ "\t|\t"+str(ugrade)+"\t|\t\t|" )
print("|\t\t| Chemistry     |    100       | \t" +str(chemistry)+"\t   | \t"+str(cstatus)+ "\t|\t"+str(cgrade)+"\t|\t\t|" )
print("|\t\t| Physics       |    100       | \t" +str(physics)+"\t   | \t"+str(pstatus)+ "\t|\t"+str(pgrade)+"\t|\t\t|" )
print("|\t\t| Mathematics   |    100       | \t" +str(maths)+"\t   | \t"+str(mstatus)+ "\t|\t"+str(mgrade)+"\t|\t\t|" )
print("|\t\t| Computer      |    100       | \t" +str(computer)+"\t   | \t"+str(costatus)+"\t|\t"+str(cograde)+"\t|\t\t|" )
print("|_______________|_______________|______________|___________________|____________|_______________|_______________|")
print("|\t\t| TOTAL         |    600       | \t" +str(total)+"\t   | \t"+str(finalstatus)+"\t|\t"+str(finalgrade)+"\t|\t\t|" )
print("|_______________|_______________|______________|___________________|____________|_______________|_______________|")
print("|\t\t|\t        |              |                   |    Percentage:  "+str(percentage)+"\t|\t\t|" )
print("|_______________|_______________|______________|___________________|____________________________|_______________|")
# Out:
# Enter your Name: Ayesha Noor
# Enter your Father Name: Noor-un-Nabi
# Enter your Roll NO: SE-2017-92
# Enter your Institute Name: Sir Syed University of Engineering and Technology
# Enter your Degree: BSSE
# Enter your Semester: 5
# Enter the marks of English: 78
# Enter the marks of Urdu: 89
# Enter the marks of Chemistry: 88
# Enter the marks of Physics: 78
# Enter the marks of Mathematics: 87
# Enter the marks of Computer: 67
# ----------------------------------------------------------------------------------------------------------------
#  Student Name: Ayesha Noor
#  Student Father's Name: Noor-un-Nabi
#  Studnet Roll No: SE-2017-92
#  Institute Name: Sir Syed University of Engineering and Technology
#  Student Degree: BSSE
# |===============================================================================================================|
# |						5rd SEMESTER MARKSHEET						|
# ...
